# %%
x<-c(10,20,30,40)

# %%
x
# Out:
# [1] 10 20 30 40

# %%
typeof(x)
# Out:
# [1] "double"

# %%
assign('y',c(50,60,70))
y
# Out:
# [1] 50 60 70

# %%
x<-c(10.25,3.5,8.75)
x
# Out:
# [1] 10.25  3.50  8.75

# %%
x<-c('a','b','z')
x
# Out:
# [1] "a" "b" "z"

# %%
x<-c(TRUE,TRUE,FALSE,TRUE)
x
# Out:
# [1]  TRUE  TRUE FALSE  TRUE

# %%
x<-c(T,T,F,T)
x
# Out:
# [1]  TRUE  TRUE FALSE  TRUE

# %%
x<-c(10,20,'a',3.5)

# %%
x
# Out:
# [1] "10"  "20"  "a"   "3.5"

# %%
x<-c(1,2,3,4,5,6)
x
# Out:
# [1] 1 2 3 4 5 6

# %%
y<-1:6

# %%
y
# Out:
# [1] 1 2 3 4 5 6

# %%
z<-seq(1,6)

# %%
z
# Out:
# [1] 1 2 3 4 5 6

# %%
z<-seq(1,6,2)

# %%
z
# Out:
# [1] 1 3 5

# %%
z<-rep(10,times=3)

# %%
z
# Out:
# [1] 10 10 10

# %%
x<-c(10,20,30)

# %%
y<-c(3.5,8.45)

# %%
z<-c(x,y)

# %%
z
# Out:
# [1] 10.00 20.00 30.00  3.50  8.45

# %%
z<-y<-x<-c(1.25,5,3)

# %%
x
# Out:
# [1] 1.25 5.00 3.00

# %%
y
# Out:
# [1] 1.25 5.00 3.00

# %%
z
# Out:
# [1] 1.25 5.00 3.00

# %%
x<-vector('numeric',length=4)

# %%
x
# Out:
# [1] 0 0 0 0

# %%
x<-vector('logical',length=4)

# %%
x
# Out:
# [1] FALSE FALSE FALSE FALSE

# %%
x<-vector('character',length=4)

# %%
x
# Out:
# [1] "" "" "" ""

# %%
x<-c(1.5,3.25,8.75)

# %%
x
# Out:
# [1] 1.50 3.25 8.75

# %%
length(x)
# Out:
# [1] 3
